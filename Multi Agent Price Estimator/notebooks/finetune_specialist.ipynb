# %% [markdown]
# ## QLoRA fine-tuning on Llama-3.2-3B (run in Colab)

# %% [markdown]
# Please refer to this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1qvAMKEzT0eyHxdyAl6Paf5j_yWbYNdGE?usp=sharing
